# %%
## 使用tavily工具
- 1.1 注册获取apikey: https://app.tavily.com/home
- 1.2 环境变量中配置TAVILY_API_KEY
- 1.3 uv add langchain-tavily 安装工具
# Out:
#   Cell In[3], line 2
#     - 1.1 注册获取apikey: https://app.tavily.com/home
#           ^
# SyntaxError: invalid syntax

# %%
import os
from dotenv import load_dotenv

load_dotenv()
print("TAVILY_API_KEY exists:", bool(os.getenv("TAVILY_API_KEY")))
# Out:
# TAVILY_API_KEY exists: True

# %%
from langchain_core.messages import HumanMessage
from langchain_community.chat_models import ChatTongyi
# 使用tavily作为web搜索工具
from langchain_tavily import TavilySearch

# 初始化工具，并设置参数，具体参数设置参考官网
tool = TavilySearch(
    max_results=5,
    topic="general",
    tavily_api_key=os.getenv("TAVILY_API_KEY"),
    # include_answer=False,
    # include_raw_content=False,
    # include_images=False,
    # include_image_descriptions=False,
    # search_depth="basic",
    # time_range="day",
    # include_domains=None,
    # exclude_domains=None
)

# tool.invoke("成都今天天气如何？")

model = ChatTongyi(model="qwen3.7-max")

# 直接使用 LLM 对象调用即可
messages = [
    {"role": "system", "content": "你是一个智能助手，你使用工具来解决用户问题", "tool": tool},
    HumanMessage(content="蒸蚌是什么梗？")
]

response = model.invoke(messages)

print(response.content)
# Out:
# “蒸蚌”是一个网络谐音梗，主要意思是 **“真绷”**（真的绷不住了）。
#
# 以下是关于这个梗的详细解析：
#
# ### 1. 词语拆解
# * **蒸**：谐音“真”。
# * **蚌**：谐音“绷”（在网络用语中，“蚌”常被用来代替“绷”，比如“蚌不住了”就是“绷不住了”的意思）。
# * 连起来“蒸蚌”就是 **“真绷”**，表示某件事太搞笑、太离谱或太荒诞，让人“真的绷不住了”。
#
# *(注：在少数语境下，它也可能被用来谐音“真棒”，带有一种调侃或反讽的语气，但“真绷”是目前最主流的用法。)*
#
# ### 2. 同类“烹饪/食物谐音梗”
# “蒸蚌”属于网络上非常流行的一系列“食物谐音梗”（有时也被称为“抽象话”或“厨房梗”），网友们用菜名或食材来表达情绪。类似的梗还有：
# * **蒸虾头** = 真下头（让人感到扫兴、无语）
# * **蒸乌鱼** = 真无语
# * **蒸栗子** = 真离谱 / 真理
# * **蒜了** = 算了
# * **蕉绿** = 焦虑
# * **泰裤辣** = 太酷啦（虽然是谐音，但常和这些梗一起出现）
#
# ### 3. 使用场景
# 当你在网上看到非常离谱的新闻、搞笑的段子、或者让人哭笑不得的操作时，就可以在评论区发一句 **“蒸蚌”** 或 **“太蒸蚌了”**，用来表达自己“真的绷不住了，想笑”的心情。
#
# 这种表达方式既带有一种幽默调侃的网感，又能巧妙地避开一些平台可能对“绷”或相关情绪词汇的限流。

# %%
from langchain_core.tools import tool
from pydantic import BaseModel, Field

## 自定义tavily工具
tavily = TavilySearch(
    max_results=5,
    topic="general",
)


# 自定封装tool
@tool
def web_search(query: str):
    """Search the web for information"""
    return tavily.invoke(query)


# Agent回答内容引用的网页信息
class Reference(BaseModel):
    title: str = Field(description="The title of the web page cited in the answer")
    url: str = Field(description="The url of the web page cited in the answer")

# Agent的回答内容
class AnswerInfo(BaseModel):
    answer: str = Field(description="The final answer for user")
    reference: list[Reference] = Field(description="The web pages cited in the answer")

# 创建智能体，使用预定义的tavily工具
model = ChatTongyi(model="qwen-plus")

# 直接使用 LLM 对象调用即可
messages = [
    {"role": "system", "content": "你是一个智能助手，你使用工具来解决用户问题", "tools": web_search},
    HumanMessage(content="蒸蚌是什么梗？")
]

response = model.invoke(messages)

print(response.content)
# Out:
# “蒸蚌”并不是一个广泛流传的网络梗，目前在主流中文互联网（如微博、B站、小红书、知乎、豆瓣等）中**没有权威或普遍认可的、成体系的“蒸蚌”梗**。经检索和分析，可能存在以下几种情况：
#
# 1. **谐音误听 / 语音梗（可能性较高）**
#    - “蒸蚌”听起来接近“真棒”（zhēn bàng），属于典型的中文谐音梗。
#    - 例如：有人故意用“蒸蚌”代替“真棒”，制造反差萌或玩“一本正经胡说八道”的效果（类似“蚌埠住了”→“绷不住了”）。
#    ✅ 这是最合理的解释：**“蒸蚌” = “真棒”的空耳/戏谑式谐音写法**，用于调侃、卖萌或规避敏感词（极少见），但并无深层含义，属于即兴玩梗，传播度低。
#
# 2. **特定圈子的小众黑话或内部玩笑**
#    - 某个游戏群、粉丝群、高校社团或地方社群中可能因某次事件（如某人ID叫“蒸蚌”，或某次翻车发言：“这题我蒸蚌！”）临时衍生出梗，但未破圈。
#    - 目前无公开证据表明其在任何亚文化圈层中有标志性事件支撑（如无相关热搜、表情包、二创视频等）。
#
# 3. **误传或错别字**
#    - 可能是“蒸包”（谐音“争包”？“真包”？）、“蒸崩”（崩溃）、“真蚌”（“蚌”在网络语中偶作“绷”的变体，如“蚌住了”=“绷不住了”）的笔误。
#    - 注意：“蚌”单独在网络用语中有时借形表音，模拟“绷”（bēng），如“蚌住”≈“绷住”，但“蒸蚌”组合暂无此用法先例。
#
# 4. **与“蒸”“蚌”字义强行关联的冷笑话（极小概率）**
#    - 如：“蒸蚌——因为蚌太硬，得上锅蒸软了才能开壳（比喻某人嘴硬/难搞）”，属临时编造的冷段子，非通用梗。
#
# 🔍 结论：
# ✅ **“蒸蚌”大概率是“真棒”的谐音恶搞写法，属于轻量级、无恶意的语音梗，类似“芜湖”“尊嘟假嘟”，但尚未形成流行度。**
# ❌ 不是出自某部影视/游戏/事件的典故梗，也非方言或专业术语。
#
# 📌 如果你是在某个具体场景（如弹幕、评论、群聊）看到这个词，欢迎补充上下文，我可以帮你精准溯源 😊
#
# 需要我帮你生成几个“蒸蚌”风格的谐音梗文案吗？比如：“这操作——蒸蚌！！！” 🦪🔥
