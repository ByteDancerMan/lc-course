# %%
## 使用tavily工具
- 1.1 注册获取apikey: https://app.tavily.com/home
- 1.2 环境变量中配置TAVILY_API_KEY
- 1.3 uv add langchain-tavily 安装工具
# Out:
#   Cell In[3], line 2
#     - 1.1 注册获取apikey: https://app.tavily.com/home
#           ^
# SyntaxError: invalid syntax

# %%
from langchain_core.messages import HumanMessage
from langchain_community.chat_models import ChatTongyi
# 使用tavily作为web搜索工具
from langchain_tavily import TavilySearch

# 初始化工具，并设置参数，具体参数设置参考官网
tool = TavilySearch(
    max_results=5,
    topic="general",
    # include_answer=False,
    # include_raw_content=False,
    # include_images=False,
    # include_image_descriptions=False,
    # search_depth="basic",
    # time_range="day",
    # include_domains=None,
    # exclude_domains=None
)

# tool.invoke("成都今天天气如何？")

model = ChatTongyi(model="qwen-plus")

# 直接使用 LLM 对象调用即可
messages = [
    {"role": "system", "content": "你是一个智能助手，你使用工具来解决用户问题", "tool": tool},
    HumanMessage(content="蒸蚌是什么梗？")
]

response = model.invoke(messages)

print(response.content)
# Out:
# C:\Users\I\AppData\Local\Temp\ipykernel_9800\4199365138.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.chat_models import ChatTongyi
# “蒸蚌”并不是一个广泛流传或有明确出处的网络梗，目前在主流中文网络平台（如微博、B站、小红书、知乎、贴吧等）中**没有权威、普遍认可的含义或典故**。经过检索和语义分析，可能的情况如下：
#
# 🔍 可能来源与推测：
#
# 1. **谐音误听/打字错误**
#    - “蒸蚌”听起来接近“真棒”（zhēn bàng），属于典型的空耳式玩梗，类似“芜湖”→“呜呼”、“尊嘟假嘟”→“真的假的”。
#    ✅ 例如：有人发“这操作太蒸蚌了！”＝“这操作太真棒了！”，用“蒸蚌”制造反差萌或卖萌效果，常见于弹幕、评论区，带点憨憨/戏精语气。
#
# 2. **特定圈子的黑话或小众玩梗**
#    - 某些游戏群、二次元社群或地方方言群中可能临时造词（如结合“蒸”+“蚌”，取“蒸熟的蚌——壳开肉露，比喻‘破防’‘被整不会了’”），但无公开传播证据，属极小范围自嗨。
#
# 3. **对“蒸”文化（如“蒸包”“蒸鱼”）的恶搞延伸？**
#    - 网络曾有“蒸XX”系列调侃（如“蒸包”指“真·蚌埠住了”），但“蒸蚌”未见成体系使用。
#    - 注：“蚌埠住了”=“绷不住了”（谐音梗），而“蚌”本身在部分语境中可代指“绷”，所以“蒸蚌”或为“蒸（谐音‘真’）+ 蚌（代‘绷’）”→“真绷”，即“真的绷不住了”。⚠️ 这属于二次谐音嵌套，较绕，多见于高玩级文字游戏，非大众梗。
#
# 4. **误传或混淆**
#    - 可能与“蚌”单独成梗混淆：“蚌”作为“绷”的谐音，常用于“蚌埠住了”；而“蒸”可能是误加或跟风叠词（如“绝绝子”→“绝绝蚌”），导致“蒸蚌”被零星误用。
#
# ✅ 当前结论：
# **“蒸蚌”不是标准网络梗，极大概率是“真棒”的空耳式卖萌写法，或极小圈层内对“蚌埠住了”的谐音再创作，尚未出圈，无固定定义。**
# 若你在某条弹幕/评论里看到它，结合上下文基本可按“真棒”或“真绷（绷不住了）”理解，属于轻松调侃语气，无需过度深究。
#
# 需要我帮你查某个具体出处（比如某条视频/帖子）吗？可以提供链接或描述，我来帮你溯源 😊

# %%
from langchain_core.tools import tool
from pydantic import BaseModel, Field

## 自定义tavily工具
tavily = TavilySearch(
    max_results=5,
    topic="general",
)


# 自定封装tool
@tool
def web_search(query: str):
    """Search the web for information"""
    return tavily.invoke(query)


# Agent回答内容引用的网页信息
class Reference(BaseModel):
    title: str = Field(description="The title of the web page cited in the answer")
    url: str = Field(description="The url of the web page cited in the answer")

# Agent的回答内容
class AnswerInfo(BaseModel):
    answer: str = Field(description="The final answer for user")
    reference: list[Reference] = Field(description="The web pages cited in the answer")

# 创建智能体，使用预定义的tavily工具
model = ChatTongyi(model="qwen-plus")

# 直接使用 LLM 对象调用即可
messages = [
    {"role": "system", "content": "你是一个智能助手，你使用工具来解决用户问题", "tools": web_search},
    HumanMessage(content="蒸蚌是什么梗？")
]

response = model.invoke(messages)

print(response.content)
# Out:
# “蒸蚌”并不是一个广泛流传或有明确出处的网络梗，目前在主流中文网络平台（如微博、B站、小红书、知乎、贴吧等）中**没有权威、普遍认可的含义或典故**。经过检索和语义分析，可能的情况如下：
#
# 🔍 可能来源与推测：
#
# 1. **谐音误听/打字错误**
#    - “蒸蚌”听起来接近“真棒”（zhēn bàng），属于典型的空耳式玩梗，类似“芜湖”→“呜呼”、“尊嘟假嘟”→“真的假的”。
#    ✅ 例如：有人发“这操作太蒸蚌了！”＝“这操作太真棒了！”，用“蒸蚌”制造反差萌或卖萌效果，常见于弹幕、评论区，带调侃或戏谑语气。
#
# 2. **特定圈子/小众玩梗（尚未破圈）**
#    - 某个UP主、主播、游戏群或校园社群中临时造词，比如结合“蒸”（网络语中有时代指“制裁”“处理掉”，如“给你蒸了”=“封号/拉黑/举报”）+“蚌”（源自“蚌埠住了”＝“绷不住了”，表破防、笑死）。
#    → “蒸蚌” = “绷不住被蒸了？” 或 “笑到被蒸”，属二次创作式抽象话，但无广泛使用证据。
#
# 3. **食材/烹饪相关误解**
#    - 蚌是淡水贝类，可蒸食（如蒜蓉蒸蚌），但“蒸蚌”作为菜名并无特殊梗点；若出现在某条美食视频弹幕中（如“这蚌蒸得也太蚌了吧！”），可能是“蚌”=“棒”的谐音混用，属即兴发挥。
#
# ❌ 排除可能性：
# - 不是出自知名影视/综艺/新闻事件（无对应热搜或出圈报道）；
# - 不是拼音缩写（如ZB、ZBQ等）、英文缩写或日/韩语转写；
# - 未见于《网络流行语词典》或近年年度热词榜单。
#
# ✅ 当前最合理解释：
# 👉 **“蒸蚌” ≈ “真棒” 的谐音变体，用于轻松、卖萌或略带敷衍的夸赞场景，属于低强度、临时性文字游戏，尚未形成固定梗文化。**
#
# 📌 类似例子参考：
# - “瑞思拜”（respect）→“respect”音译+戏谑化
# - “夺笋”（多损）→“多损呐”谐音，表离谱
# - “哈基米”（hakimi）→原为日语拟声，后泛化为可爱代称
#
# 💡 建议：
# 如你是在某条具体弹幕、评论或视频中看到“蒸蚌”，欢迎提供上下文（如截图描述、平台、发言场景），我可以帮你精准溯源解析！
#
# 需要我帮你生成一句“蒸蚌”风格的夸夸文案吗？😄
