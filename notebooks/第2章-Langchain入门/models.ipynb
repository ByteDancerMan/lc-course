# %%
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("DASHSCOPE_API_KEY")

# %%
from langchain.agents import create_agent
from langchain_community.chat_models.tongyi import ChatTongyi

# 1.使用Model类初始化模型，必须开启 streaming=True 才能实现真正的流式输出
model = ChatTongyi(
    model="qwen-plus",
    streaming=True
    # 其它模型参数...
)

# 2.使用初始化好的model创建智能体
agent = create_agent(model=model)

# %%
for token, metadata in agent.stream(
    {"messages": [{"role": "user", "content": "月亮的首都是哪里？"}]},
    stream_mode="messages"
):
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# 月亮没有首都，因为它不是国家，也没有政府、人口或主权实体。
#
# “首都”是主权国家或某些行政区划（如省、州）的行政中心，而月球是地球唯一的天然卫星，是一颗天体，属于自然天体，不具备政治属性。目前国际社会（依据1967年《外层空间条约》）明确规定：外层空间（包括月球和其他天体）不得由国家通过主权主张、使用或占领等方式据为己有；月球及其资源属于全人类共同利益，任何国家不得宣称主权。
#
# 虽然各国（如中国、美国、印度等）在月球开展探测任务，并设有月球探测工程的地面指挥中心（例如中国的北京航天飞行控制中心），但这些只是地球上的科研与指挥机构，并非月球的“首都”。
#
# ✅ 小结：
# 🌙 月球没有首都；
# 🌍 首都概念仅适用于人类政治实体；
# 🛰️ 月球是全人类共同探索与和平利用的领域。
#
# 如果你是在玩文字游戏或看到某个虚构作品（如科幻小说、动漫）中设定“月亮首都”，欢迎补充背景，我可以帮你解析那个设定 😊
